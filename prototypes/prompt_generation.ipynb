# %%
import os
import sys
module_dir = os.path.abspath('../utils') 
sys.path.append(module_dir)
import document_reader as readdoc
import pdf_file_upload as pfu

# %%
pfu.load_file(on_complete=pfu.process_file)
# Out:
# FileUpload(value=(), accept='.pdf', description='Upload')
# Button(button_style='primary', description='Load File', style=ButtonStyle())
# Output()

# %%
file = pfu.get_file()
# Out:
# Start Function
# Number of bytes: 277459

# %%
text = readdoc.extract_pages_from_pdf(file)

# %%
program_context = '\n'.join(item['text'] for item in text[1:])

# %%
i, x in enumerate text
# Out:
#   Cell In[20], line 1
#     i, x in enumerate text
#                       ^
# SyntaxError: invalid syntax
