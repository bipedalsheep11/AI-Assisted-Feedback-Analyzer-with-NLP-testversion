# %%
import streamlit as st

# %%
st.write("Hello world")
# Out:
# 2026-03-03 11:54:11.346 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-03 11:54:11.695
# ...
#   command:
#
#     streamlit run C:\sean-files\AI-Assisted-Feedback-Analyzer-with-NLP\main-project-env\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-03 11:54:11.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-03 11:54:11.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
